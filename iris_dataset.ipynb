# %%
from sklearn.neighbors import NearestNeighbors

label_mapping = {"Iris-setosa\n": 0, 
                 "Iris-versicolor\n": 1, 
                 "Iris-virginica\n": 2}

point_set = []
with open("iris.txt", "r") as file:
    lines = file.readlines()
    lines = lines[:-2]
    for line in lines:
        split = line.split(" ")
        f1, f2, f3, f4, label = split
        point_set.append((f2, f3, label_mapping[label]))

point_set
# Out:
# [('3.5', '1.4', 0),
#  ('3.0', '1.4', 0),
#  ('3.2', '1.3', 0),
#  ('3.1', '1.5', 0),
#  ('3.6', '1.4', 0),
#  ('3.9', '1.7', 0),
#  ('3.4', '1.4', 0),
#  ('3.4', '1.5', 0),
#  ('2.9', '1.4', 0),
#  ('3.1', '1.5', 0),
#  ('3.7', '1.5', 0),
#  ('3.4', '1.6', 0),
#  ('3.0', '1.4', 0),
#  ('3.0', '1.1', 0),
#  ('4.0', '1.2', 0),
#  ('4.4', '1.5', 0),
#  ('3.9', '1.3', 0),
#  ('3.5', '1.4', 0),
#  ('3.8', '1.7', 0),
#  ('3.8', '1.5', 0),
#  ('3.4', '1.7', 0),
#  ('3.7', '1.5', 0),
#  ('3.6', '1.0', 0),
#  ('3.3', '1.7', 0),
#  ('3.4', '1.9', 0),
#  ('3.0', '1.6', 0),
#  ('3.4', '1.6', 0),
#  ('3.5', '1.5', 0),
#  ('3.4', '1.4', 0),
#  ('3.2', '1.6', 0),
#  ('3.1', '1.6', 0),
#  ('3.4', '1.5', 0),
#  ('4.1', '1.5', 0),
#  ('4.2', '1.4', 0),
#  ('3.1', '1.5', 0),
#  ('3.2', '1.2', 0),
#  ('3.5', '1.3', 0),
#  ('3.1', '1.5', 0),
#  ('3.0', '1.3', 0),
#  ('3.4', '1.5', 0),
#  ('3.5', '1.3', 0),
#  ('2.3', '1.3', 0),
#  ('3.2', '1.3', 0),
#  ('3.5', '1.6', 0),
#  ('3.8', '1.9', 0),
#  ('3.0', '1.4', 0),
#  ('3.8', '1.6', 0),
#  ('3.2', '1.4', 0),
#  ('3.7', '1.5', 0),
#  ('3.3', '1.4', 0),
#  ('3.2', '4.7', 1),
#  ('3.2', '4.5', 1),
#  ('3.1', '4.9', 1),
#  ('2.3', '4.0', 1),
#  ('2.8', '4.6', 1),
#  ('2.8', '4.5', 1),
#  ('3.3', '4.7', 1),
#  ('2.4', '3.3', 1),
#  ('2.9', '4.6', 1),
#  ('2.7', '3.9', 1),
#  ('2.0', '3.5', 1),
#  ('3.0', '4.2', 1),
#  ('2.2', '4.0', 1),
#  ('2.9', '4.7', 1),
#  ('2.9', '3.6', 1),
#  ('3.1', '4.4', 1),
#  ('3.0', '4.5', 1),
#  ('2.7', '4.1', 1),
#  ('2.2', '4.5', 1),
#  ('2.5', '3.9', 1),
#  ('3.2', '4.8', 1),
#  ('2.8', '4.0', 1),
#  ('2.5', '4.9', 1),
#  ('2.8', '4.7', 1),
#  ('2.9', '4.3', 1),
#  ('3.0', '4.4', 1),
#  ('2.8', '4.8', 1),
#  ('3.0', '5.0', 1),
#  ('2.9', '4.5', 1),
#  ('2.6', '3.5', 1),
#  ('2.4', '3.8', 1),
#  ('2.4', '3.7', 1),
#  ('2.7', '3.9', 1),
#  ('2.7', '5.1', 1),
#  ('3.0', '4.5', 1),
#  ('3.4', '4.5', 1),
#  ('3.1', '4.7', 1),
#  ('2.3', '4.4', 1),
#  ('3.0', '4.1', 1),
#  ('2.5', '4.0', 1),
#  ('2.6', '4.4', 1),
#  ('3.0', '4.6', 1),
#  ('2.6', '4.0', 1),
#  ('2.3', '3.3', 1),
#  ('2.7', '4.2', 1),
#  ('3.0', '4.2', 1),
#  ('2.9', '4.2', 1),
#  ('2.9', '4.3', 1),
#  ('2.5', '3.0', 1),
#  ('2.8', '4.1', 1),
#  ('3.3', '6.0', 2),
#  ('2.7', '5.1', 2),
#  ('3.0', '5.9', 2),
#  ('2.9', '5.6', 2),
#  ('3.0', '5.8', 2),
#  ('3.0', '6.6', 2),
#  ('2.5', '4.5', 2),
#  ('2.9', '6.3', 2),
#  ('2.5', '5.8', 2),
#  ('3.6', '6.1', 2),
#  ('3.2', '5.1', 2),
#  ('2.7', '5.3', 2),
#  ('3.0', '5.5', 2),
#  ('2.5', '5.0', 2),
#  ('2.8', '5.1', 2),
#  ('3.2', '5.3', 2),
#  ('3.0', '5.5', 2),
#  ('3.8', '6.7', 2),
#  ('2.6', '6.9', 2),
#  ('2.2', '5.0', 2),
#  ('3.2', '5.7', 2),
#  ('2.8', '4.9', 2),
#  ('2.8', '6.7', 2),
#  ('2.7', '4.9', 2),
#  ('3.3', '5.7', 2),
#  ('3.2', '6.0', 2),
#  ('2.8', '4.8', 2),
#  ('3.0', '4.9', 2),
#  ('2.8', '5.6', 2),
#  ('3.0', '5.8', 2),
#  ('2.8', '6.1', 2),
#  ('3.8', '6.4', 2),
#  ('2.8', '5.6', 2),
#  ('2.8', '5.1', 2),
#  ('2.6', '5.6', 2),
#  ('3.0', '6.1', 2),
#  ('3.4', '5.6', 2),
#  ('3.1', '5.5', 2),
#  ('3.0', '4.8', 2),
#  ('3.1', '5.4', 2),
#  ('3.1', '5.6', 2),
#  ('3.1', '5.1', 2),
#  ('2.7', '5.1', 2),
#  ('3.2', '5.9', 2),
#  ('3.3', '5.7', 2),
#  ('3.0', '5.2', 2),
#  ('2.5', '5.0', 2),
#  ('3.0', '5.2', 2),
#  ('3.4', '5.4', 2),
#  ('3.0', '5.1', 2)]

# %%
### experiment 1 ###
for k in [1, 3, 5, 7, 9]:
    for p in []
    KNN = NearestNeighbors(n_neighbors=5, algorithm='ball_tree')
